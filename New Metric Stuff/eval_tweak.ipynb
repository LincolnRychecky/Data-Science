# %%
import argparse
import os
import lightgbm as lgb
import numpy as np
import pandas as pd
from pprint import pprint
from azureml.core import Run
import joblib
from sklearn.metrics import (confusion_matrix, f1_score, accuracy_score,
                             precision_score, recall_score)
from imblearn.metrics import geometric_mean_score
from mlpackage.utility import ml_model as mf

# %%
ID_COLUMN = 'id'
DATE_COLUMN = 'dateTime'
LABEL_COLUMN = 'Label'

# %%
base_dir = '/Users/anders.swanson/temp/output'

# %%
# parameters
parser = argparse.ArgumentParser()
parser.add_argument('-file')
# params: Estimator
parser.add_argument('--input_dir', dest="input_dir",
                    default=os.path.join(base_dir, 'split_data3'))
parser.add_argument('--output_dir', dest="output_dir",
                    default=os.path.join(base_dir, 'trained_model3'))
parser.add_argument('--data_name', dest="data_name", default="deal_data3")
parser.add_argument('--model_name', dest="model_name", default="deal_model3")

# params: LightGBM (from AutoML)
parser.add_argument('--boosting_type', type=str,
                    dest='boosting_type', default="gbdt")
parser.add_argument('--colsample_bytree', type=float,
                    dest='colsample_bytree', default=0.7922222222222222)
parser.add_argument('--importance_type', type=str, dest='importance_type', default='split')
parser.add_argument('--learning_rate', type=float,
                    dest='learning_rate', default=0.05263631578947369)
parser.add_argument('--max_bin', type=int, dest='max_bin', default=50)
parser.add_argument('--max_depth', type=int, dest='max_depth', default=8)
parser.add_argument('--min_child_samples', type=int,
                    dest='min_child_samples', default=351)
parser.add_argument('--min_child_weight', type=int,
                    dest='min_child_weight', default=2)
parser.add_argument('--min_split_gain', type=int,
                    dest='min_split_gain', default=0.9473684210526315)
parser.add_argument('--n_estimators', type=int,
                    dest='n_estimators', default=800)
parser.add_argument('--n_jobs', type=int,
                    dest='n_jobs', default=1)
parser.add_argument('--num_leaves', type=int, dest='num_leaves', default=170)
parser.add_argument('--objective', type=str,
                    dest='objective', default=None)
parser.add_argument('--random_state', type=int,
                    dest='random_state', default=None)
parser.add_argument('--reg_alpha', type=float,
                    dest='reg_alpha', default=0.7894736842105263)
parser.add_argument('--reg_lambda', type=float,
                    dest='reg_lambda', default=0.05263157894736842)
parser.add_argument('--silent', type=bool,
                    dest='silent', default=True)
parser.add_argument('--subsample', type=float, dest='subsample', default=0.8910526315789474)
parser.add_argument('--subsample_for_bin', type=int,
                    dest='subsample_for_bin', default=200000)
parser.add_argument('--subsample_freq', type=int,
                    dest='subsample_freq', default=0)
parser.add_argument('--verbose', type=int,
                    dest='verbose', default=-10)

args = parser.parse_args()
print("all args: ")
pprint(vars(args))

# create training args dict
params_dict = dict(**vars(args))
est_params = ['input_dir', 'output_dir', 'model_name', 'stage', 'data_name']
for value in est_params:
    params_dict.pop(value, None)
# Out:
# all args:
# {'boosting_type': 'gbdt',
#  'colsample_bytree': 0.7922222222222222,
#  'data_name': 'deal_data3',
#  'file': 'C:\\Users\\lincoln.rychecky\\AppData\\Roaming\\jupyter\\runtime\\kernel-a4f9508e-2c5d-43d3-8998-9a2cf01da365.json',
#  'importance_type': 'split',
#  'input_dir': '/Users/anders.swanson/temp/output\\split_data3',
#  'learning_rate': 0.05263631578947369,
#  'max_bin': 50,
#  'max_depth': 8,
#  'min_child_samples': 351,
#  'min_child_weight': 2,
#  'min_split_gain': 0.9473684210526315,
#  'model_name': 'deal_model3',
#  'n_estimators': 800,
#  'n_jobs': 1,
#  'num_leaves': 170,
#  'objective': None,
#  'output_dir': '/Users/anders.swanson/temp/output\\trained_model3',
#  'random_state': None,
#  'reg_alpha': 0.7894736842105263,
#  'reg_lambda': 0.05263157894736842,
#  'silent': True,
#  'subsample': 0.8910526315789474,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0,
#  'verbose': -10}

# %%
def f1_score_wrapper(y_true, y_pred):
    """
    *Calculate the f1-score (weighted) given an array of actuals and an array of predictions

    *Args:
        *y_true (Array): Actual labels
        *y_pred (Array): Predicted labels

    *Returns:
        *f1-weighted: Harmonic mean of precision and recall for each class, weighted by class support and summed
    """
    return ('f1-weighted', f1_score(y_true, [1 if y >= 0.5 else 0 for y in y_pred], average='weighted'), 1)


def calc_recall_rate(df, probability):
    """
    *Determine attrition rate above specified probability threshold

    *Args:
        *df (Dataframe): The dataframe for which to calculate the attrition rate.
        *probability (Numeric): The probability threshold above which to calculate the attrition rate.

    *Returns:
        *rate: Percentage of attrition above some threshold
        *threshold: Threshold above which to calculate attrition rate
    """
    target = len(df) * probability
    threshold = np.argmin([abs(len(df[df['Probability'] >= x]) - target) for x in np.arange(0, 1, 0.01)]) / 100
    print('LIFT: for probability={} threshold is {}'.format(probability, threshold))
    return ((df['TMP_LABEL'] >= 1) & (df['Probability'] >= threshold)).sum() /\
        (df['Probability'] >= threshold).sum(), threshold


def train_model(args_dict, data, early_stopping_rounds=None):
    """
    *Train a gradient boosted decision tree model

    *Args:
        *params_dict (): The arguments of the classifier
        *data (Dataframe): Data to use for training
        *early_stopping_rounds (Numeric): How many early stopping rounds to use

    *Returns:
        *clf: Trained classifier
    """
    clf = lgb.LGBMClassifier(metric='None', **params_dict)
    clf.fit(
        X=data['X'],
        y=data['y'],
        eval_set=[(data['x_valid'], data['y_valid'])],
        eval_metric=f1_score_wrapper,
        early_stopping_rounds=early_stopping_rounds
    )
    return clf


def make_preevaluation_df(clf, x, xtra_cols, y, cols):
    """
    *Determine lift which is defined as the positive rate among top 10% of scored probabilities divided
    * by the positive rate of the overall population.

    *Args:
        *clf (): The classifier to score probabilities with
        *x (Dataframe): The feature set
        *xtra_cols (Dataframe): the extra labels
        *y (np.ndarray): The true Label. If `None`, 'Label' col will be 0.5
        *cols (List(String)): either
            cols to add to df: deal: ['id']; attrition:  ['id', 'DateOfExport']),
            or `None` if you want to include all cols from `xtra_cols`

    *Returns:
        * (Dataframe): id, Probability (predicted), Label (actual result) (and sometimes DateOfExport)
    """
    label_col = y if y is not None else 0.5

    df = (xtra_cols
          # subset where needed
          .pipe(lambda x: x[cols] if cols is not None else x)
          # predict on every row in holdout
          .assign(Probability=clf.predict_proba(x)[:, 1])
          # TODO : verify that we aren't predicting for the current month....
          .assign(Label=label_col)
          )
    return df


def get_metrics(df_preeval):
    """
    * Get accuracy metrics for a given set of observations+labels

    *Args:
        *df_preeval: output of make_preevaluation_df()

    *Returns:
        *metrics: dict containing accuracy, precision, recall, g-mean and f1
        *conf_to_log: json struct for logging to ML Service
        *conf: a sklearn confusion matrix
    """

    y_test = df_preeval["Label"]
    y_pred = [0.0 if x < 0.5 else 1.0 for x in df_preeval["Probability"]]
    conf_pre = confusion_matrix(y_test, y_pred)

    conf_to_log = {
        "schema_type": "confusion_matrix",
        "schema_version": "v1",
        "data": {
            "class_labels": ["0", "1"],
            "matrix": conf_pre.tolist()}
    }
    conf = pd.DataFrame(
        conf_pre,
        index=["actualFALSE", "actualTRUE"],
        columns=["predFALSE", "predTRUE"]).reset_index()

    metrics = {
        'accuracy': accuracy_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred, average='binary'),
        'recall': recall_score(y_test, y_pred, average='binary'),
        'geometric_mean': geometric_mean_score(y_test, y_pred),
        'f1': f1_score(y_test, y_pred, average='binary'),
    }

    return metrics, conf_to_log, conf

# %%
def geometric_mean_score_wrapper(y_true, y_pred):
    """
    *Calculate the g-mean given an array of actuals and an array of predictions

    *Args:
        *y_true (Array): Actual labels
        *y_pred (Array): Predicted labels

    *Returns:
        *geometric mean: Geometric mean of precision and recall
    """
    return ('geometric mean', geometric_mean_score(y_true, [1 if y >= 0.5 else
                                                            0 for y in y_pred]), 1)

def train_model(args_dict, data, eval_func_wrapper, early_stopping_rounds=None):
    """
    *Train a gradient boosted decision tree model

    *Args:
        *args_dict (): The arguments of the classifier
        *data (Dataframe): Data to use for training
        *early_stopping_rounds (Numeric): How many early stopping rounds to use

    *Returns:
        *clf: Trained classifier
    """
    clf = lgb.LGBMClassifier(metric='None', **args_dict)
    clf.fit(
        X=data['X'],
        y=data['y'],
        eval_set=[(data['x_valid'], data['y_valid'])],
#         eval_metric=eval_func_wrapper,
        early_stopping_rounds=early_stopping_rounds
    )
    return clf

# %%
# INPUTS
# load train and test set into numpy arrays
data = joblib.load(os.path.join(args.input_dir, args.data_name + '.pkl'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-28a9560d349e> in <module>
#       1 # INPUTS
#       2 # load train and test set into numpy arrays
# ----> 3 data = joblib.load(os.path.join(args.input_dir, args.data_name + '.pkl'))
#
# ~\Anaconda3\envs\deal\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode)
#     595             obj = _unpickle(fobj)
#     596     else:
# --> 597         with open(filename, 'rb') as f:
#     598             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     599                 if isinstance(fobj, _basestring):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/anders.swanson/temp/output\\split_data3\\deal_data3.pkl'

# %%
def demo_score(prob,act):
    return ((prob-act)**2).mean()

def crazy_wrapper(y_true, y_pred):
    """
    *Calculate the f1-score (weighted) given an array of actuals and an array of predictions

    *Args:
        *y_true (Array): Actual labels
        *y_pred (Array): Predicted labels

    *Returns:
        *f1-weighted: Harmonic mean of precision and recall for each class, weighted by class support and summed
    """
    return ('crazy_metric', demo_score(y_pred, y_true), 1)

# %%
clf = lgb.LGBMClassifier(metric='None', **params_dict)
clf.fit(
    X=data['X'],
    y=data['y'],
    eval_set=[(data['x_valid'], data['y_valid'])],
    eval_metric=crazy_wrapper,
    early_stopping_rounds=50
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a248f71426da> in <module>
#       1 clf = lgb.LGBMClassifier(metric='None', **params_dict)
#       2 clf.fit(
# ----> 3     X=data['X'],
#       4     y=data['y'],
#       5     eval_set=[(data['x_valid'], data['y_valid'])],
#
# NameError: name 'data' is not defined

# %%
# train model (w/ params from CL args)
clf = train_model(params_dict, data, early_stopping_rounds=50)
# Out:
# [1]	valid_0's binary_error: 0.403105
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's binary_error: 0.403105
# [3]	valid_0's binary_error: 0.403105
# [4]	valid_0's binary_error: 0.393905
# [5]	valid_0's binary_error: 0.352789
# [6]	valid_0's binary_error: 0.321737
# [7]	valid_0's binary_error: 0.305923
# [8]	valid_0's binary_error: 0.295285
# [9]	valid_0's binary_error: 0.283784
# [10]	valid_0's binary_error: 0.278033
# [11]	valid_0's binary_error: 0.273145
# [12]	valid_0's binary_error: 0.269695
# [13]	valid_0's binary_error: 0.267683
# [14]	valid_0's binary_error: 0.265095
# [15]	valid_0's binary_error: 0.26107
# [16]	valid_0's binary_error: 0.258482
# [17]	valid_0's binary_error: 0.254169
# [18]	valid_0's binary_error: 0.251581
# [19]	valid_0's binary_error: 0.253019
# [20]	valid_0's binary_error: 0.249569
# [21]	valid_0's binary_error: 0.250719
# [22]	valid_0's binary_error: 0.250431
# [23]	valid_0's binary_error: 0.250144
# [24]	valid_0's binary_error: 0.250144
# [25]	valid_0's binary_error: 0.248706
# [26]	valid_0's binary_error: 0.246406
# [27]	valid_0's binary_error: 0.243243
# [28]	valid_0's binary_error: 0.241806
# [29]	valid_0's binary_error: 0.238355
# [30]	valid_0's binary_error: 0.238643
# [31]	valid_0's binary_error: 0.236918
# [32]	valid_0's binary_error: 0.237205
# [33]	valid_0's binary_error: 0.234618
# [34]	valid_0's binary_error: 0.23433
# [35]	valid_0's binary_error: 0.234618
# [36]	valid_0's binary_error: 0.234618
# [37]	valid_0's binary_error: 0.235768
# [38]	valid_0's binary_error: 0.23318
# [39]	valid_0's binary_error: 0.234043
# [40]	valid_0's binary_error: 0.233755
# [41]	valid_0's binary_error: 0.23088
# [42]	valid_0's binary_error: 0.230017
# [43]	valid_0's binary_error: 0.22973
# [44]	valid_0's binary_error: 0.228867
# [45]	valid_0's binary_error: 0.228005
# [46]	valid_0's binary_error: 0.227717
# [47]	valid_0's binary_error: 0.226279
# [48]	valid_0's binary_error: 0.227142
# [49]	valid_0's binary_error: 0.225417
# [50]	valid_0's binary_error: 0.225417
# [51]	valid_0's binary_error: 0.223692
# [52]	valid_0's binary_error: 0.225129
# [53]	valid_0's binary_error: 0.223979
# [54]	valid_0's binary_error: 0.223404
# [55]	valid_0's binary_error: 0.224554
# [56]	valid_0's binary_error: 0.224267
# [57]	valid_0's binary_error: 0.224554
# [58]	valid_0's binary_error: 0.225129
# [59]	valid_0's binary_error: 0.225417
# [60]	valid_0's binary_error: 0.223404
# [61]	valid_0's binary_error: 0.222542
# [62]	valid_0's binary_error: 0.221392
# [63]	valid_0's binary_error: 0.221679
# [64]	valid_0's binary_error: 0.221392
# [65]	valid_0's binary_error: 0.221104
# [66]	valid_0's binary_error: 0.221392
# [67]	valid_0's binary_error: 0.219954
# [68]	valid_0's binary_error: 0.223117
# [69]	valid_0's binary_error: 0.222829
# [70]	valid_0's binary_error: 0.222829
# [71]	valid_0's binary_error: 0.221679
# [72]	valid_0's binary_error: 0.221104
# [73]	valid_0's binary_error: 0.219954
# [74]	valid_0's binary_error: 0.221104
# [75]	valid_0's binary_error: 0.221392
# [76]	valid_0's binary_error: 0.221967
# [77]	valid_0's binary_error: 0.221392
# [78]	valid_0's binary_error: 0.222254
# [79]	valid_0's binary_error: 0.220242
# [80]	valid_0's binary_error: 0.220817
# [81]	valid_0's binary_error: 0.221104
# [82]	valid_0's binary_error: 0.221104
# [83]	valid_0's binary_error: 0.220529
# [84]	valid_0's binary_error: 0.219091
# [85]	valid_0's binary_error: 0.219091
# [86]	valid_0's binary_error: 0.219379
# [87]	valid_0's binary_error: 0.219666
# [88]	valid_0's binary_error: 0.219091
# [89]	valid_0's binary_error: 0.220529
# [90]	valid_0's binary_error: 0.220529
# [91]	valid_0's binary_error: 0.220817
# [92]	valid_0's binary_error: 0.221104
# [93]	valid_0's binary_error: 0.220817
# [94]	valid_0's binary_error: 0.220529
# [95]	valid_0's binary_error: 0.218516
# [96]	valid_0's binary_error: 0.218516
# [97]	valid_0's binary_error: 0.218516
# [98]	valid_0's binary_error: 0.218804
# [99]	valid_0's binary_error: 0.219379
# [100]	valid_0's binary_error: 0.219666
# [101]	valid_0's binary_error: 0.219091
# [102]	valid_0's binary_error: 0.217654
# [103]	valid_0's binary_error: 0.217941
# [104]	valid_0's binary_error: 0.217941
# [105]	valid_0's binary_error: 0.217941
# [106]	valid_0's binary_error: 0.217654
# [107]	valid_0's binary_error: 0.216216
# [108]	valid_0's binary_error: 0.217079
# [109]	valid_0's binary_error: 0.215641
# [110]	valid_0's binary_error: 0.215066
# [111]	valid_0's binary_error: 0.215929
# [112]	valid_0's binary_error: 0.216504
# [113]	valid_0's binary_error: 0.216216
# [114]	valid_0's binary_error: 0.216504
# [115]	valid_0's binary_error: 0.216216
# [116]	valid_0's binary_error: 0.215929
# [117]	valid_0's binary_error: 0.216504
# [118]	valid_0's binary_error: 0.215929
# [119]	valid_0's binary_error: 0.215354
# [120]	valid_0's binary_error: 0.215354
# [121]	valid_0's binary_error: 0.215066
# [122]	valid_0's binary_error: 0.216216
# [123]	valid_0's binary_error: 0.216216
# [124]	valid_0's binary_error: 0.216216
# [125]	valid_0's binary_error: 0.216216
# [126]	valid_0's binary_error: 0.215929
# [127]	valid_0's binary_error: 0.216791
# [128]	valid_0's binary_error: 0.217941
# [129]	valid_0's binary_error: 0.217941
# [130]	valid_0's binary_error: 0.217654
# [131]	valid_0's binary_error: 0.217654
# [132]	valid_0's binary_error: 0.217654
# [133]	valid_0's binary_error: 0.218229
# [134]	valid_0's binary_error: 0.218516
# [135]	valid_0's binary_error: 0.218229
# [136]	valid_0's binary_error: 0.218804
# [137]	valid_0's binary_error: 0.218804
# [138]	valid_0's binary_error: 0.218229
# [139]	valid_0's binary_error: 0.218229
# [140]	valid_0's binary_error: 0.218516
# [141]	valid_0's binary_error: 0.218516
# [142]	valid_0's binary_error: 0.217941
# [143]	valid_0's binary_error: 0.217366
# [144]	valid_0's binary_error: 0.217941
# [145]	valid_0's binary_error: 0.218229
# [146]	valid_0's binary_error: 0.218229
# [147]	valid_0's binary_error: 0.217079
# [148]	valid_0's binary_error: 0.218229
# [149]	valid_0's binary_error: 0.217941
# [150]	valid_0's binary_error: 0.218516
# [151]	valid_0's binary_error: 0.217079
# [152]	valid_0's binary_error: 0.217941
# [153]	valid_0's binary_error: 0.217079
# [154]	valid_0's binary_error: 0.217654
# [155]	valid_0's binary_error: 0.217366
# [156]	valid_0's binary_error: 0.216791
# [157]	valid_0's binary_error: 0.216504
# [158]	valid_0's binary_error: 0.215354
# [159]	valid_0's binary_error: 0.215354
# [160]	valid_0's binary_error: 0.215354
# Early stopping, best iteration is:
# [110]	valid_0's binary_error: 0.215066

# %%
# HACK: due to early stopping bug, re-run model on best # iterations
params_dict['n_estimators'] = clf.best_iteration_
clf = train_model(params_dict, data)
# Out:
# [1]	valid_0's geometric mean: 0
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's geometric mean: 0
# [3]	valid_0's geometric mean: 0
# [4]	valid_0's geometric mean: 0.153383
# [5]	valid_0's geometric mean: 0.373714
# [6]	valid_0's geometric mean: 0.494396
# [7]	valid_0's geometric mean: 0.542873
# [8]	valid_0's geometric mean: 0.575456
# [9]	valid_0's geometric mean: 0.606023
# [10]	valid_0's geometric mean: 0.623658
# [11]	valid_0's geometric mean: 0.639595
# [12]	valid_0's geometric mean: 0.652282
# [13]	valid_0's geometric mean: 0.658584
# [14]	valid_0's geometric mean: 0.667219
# [15]	valid_0's geometric mean: 0.677638
# [16]	valid_0's geometric mean: 0.683231
# [17]	valid_0's geometric mean: 0.690949
# [18]	valid_0's geometric mean: 0.69505
# [19]	valid_0's geometric mean: 0.697233
# [20]	valid_0's geometric mean: 0.703351
# [21]	valid_0's geometric mean: 0.702576
# [22]	valid_0's geometric mean: 0.704013
# [23]	valid_0's geometric mean: 0.705681
# [24]	valid_0's geometric mean: 0.707615
# [25]	valid_0's geometric mean: 0.710973
# [26]	valid_0's geometric mean: 0.715579
# [27]	valid_0's geometric mean: 0.720283
# [28]	valid_0's geometric mean: 0.723297
# [29]	valid_0's geometric mean: 0.728145
# [30]	valid_0's geometric mean: 0.728803
# [31]	valid_0's geometric mean: 0.731527
# [32]	valid_0's geometric mean: 0.731532
# [33]	valid_0's geometric mean: 0.735484
# [34]	valid_0's geometric mean: 0.736312
# [35]	valid_0's geometric mean: 0.736515
# [36]	valid_0's geometric mean: 0.736923
# [37]	valid_0's geometric mean: 0.735478
# [38]	valid_0's geometric mean: 0.738779
# [39]	valid_0's geometric mean: 0.738555
# [40]	valid_0's geometric mean: 0.739565
# [41]	valid_0's geometric mean: 0.742857
# [42]	valid_0's geometric mean: 0.744473
# [43]	valid_0's geometric mean: 0.745269
# [44]	valid_0's geometric mean: 0.746099
# [45]	valid_0's geometric mean: 0.747701
# [46]	valid_0's geometric mean: 0.747721
# [47]	valid_0's geometric mean: 0.749359
# [48]	valid_0's geometric mean: 0.748722
# [49]	valid_0's geometric mean: 0.750572
# [50]	valid_0's geometric mean: 0.750954
# [51]	valid_0's geometric mean: 0.75337
# [52]	valid_0's geometric mean: 0.751736
# [53]	valid_0's geometric mean: 0.752968
# [54]	valid_0's geometric mean: 0.754334
# [55]	valid_0's geometric mean: 0.753476
# [56]	valid_0's geometric mean: 0.75369
# [57]	valid_0's geometric mean: 0.753476
# [58]	valid_0's geometric mean: 0.753232
# [59]	valid_0's geometric mean: 0.753202
# [60]	valid_0's geometric mean: 0.755444
# [61]	valid_0's geometric mean: 0.755905
# [62]	valid_0's geometric mean: 0.757685
# [63]	valid_0's geometric mean: 0.757469
# [64]	valid_0's geometric mean: 0.758231
# [65]	valid_0's geometric mean: 0.758447
# [66]	valid_0's geometric mean: 0.757685
# [67]	valid_0's geometric mean: 0.759855
# [68]	valid_0's geometric mean: 0.756208
# [69]	valid_0's geometric mean: 0.756058
# [70]	valid_0's geometric mean: 0.756787
# [71]	valid_0's geometric mean: 0.757833
# [72]	valid_0's geometric mean: 0.758628
# [73]	valid_0's geometric mean: 0.759855
# [74]	valid_0's geometric mean: 0.758809
# [75]	valid_0's geometric mean: 0.758592
# [76]	valid_0's geometric mean: 0.757435
# [77]	valid_0's geometric mean: 0.758412
# [78]	valid_0's geometric mean: 0.757762
# [79]	valid_0's geometric mean: 0.760534
# [80]	valid_0's geometric mean: 0.759743
# [81]	valid_0's geometric mean: 0.759882
# [82]	valid_0's geometric mean: 0.759526
# [83]	valid_0's geometric mean: 0.760139
# [84]	valid_0's geometric mean: 0.761582
# [85]	valid_0's geometric mean: 0.761582
# [86]	valid_0's geometric mean: 0.761186
# [87]	valid_0's geometric mean: 0.76079
# [88]	valid_0's geometric mean: 0.76176
# [89]	valid_0's geometric mean: 0.760139
# [90]	valid_0's geometric mean: 0.760139
# [91]	valid_0's geometric mean: 0.760277
# [92]	valid_0's geometric mean: 0.760059
# [93]	valid_0's geometric mean: 0.7601
# [94]	valid_0's geometric mean: 0.760672
# [95]	valid_0's geometric mean: 0.762902
# [96]	valid_0's geometric mean: 0.763603
# [97]	valid_0's geometric mean: 0.763603
# [98]	valid_0's geometric mean: 0.762684
# [99]	valid_0's geometric mean: 0.762424
# [100]	valid_0's geometric mean: 0.76203
# [101]	valid_0's geometric mean: 0.762466
# [102]	valid_0's geometric mean: 0.763908
# [103]	valid_0's geometric mean: 0.76369
# [104]	valid_0's geometric mean: 0.763514
# [105]	valid_0's geometric mean: 0.763865
# [106]	valid_0's geometric mean: 0.764433
# [107]	valid_0's geometric mean: 0.765526
# [108]	valid_0's geometric mean: 0.764344
# [109]	valid_0's geometric mean: 0.766486
# [110]	valid_0's geometric mean: 0.766923
# [111]	valid_0's geometric mean: 0.765919
# [112]	valid_0's geometric mean: 0.765132
# [113]	valid_0's geometric mean: 0.7657
# [114]	valid_0's geometric mean: 0.765307
# [115]	valid_0's geometric mean: 0.765526
# [116]	valid_0's geometric mean: 0.766093
# [117]	valid_0's geometric mean: 0.76583
# [118]	valid_0's geometric mean: 0.766267
# [119]	valid_0's geometric mean: 0.767225
# [120]	valid_0's geometric mean: 0.767225
# [121]	valid_0's geometric mean: 0.767617
# [122]	valid_0's geometric mean: 0.766048
# [123]	valid_0's geometric mean: 0.766222
# [124]	valid_0's geometric mean: 0.766395
# [125]	valid_0's geometric mean: 0.766222
# [126]	valid_0's geometric mean: 0.766267
# [127]	valid_0's geometric mean: 0.764914
# [128]	valid_0's geometric mean: 0.76369
# [129]	valid_0's geometric mean: 0.76369
# [130]	valid_0's geometric mean: 0.763908
# [131]	valid_0's geometric mean: 0.763732
# [132]	valid_0's geometric mean: 0.763908
# [133]	valid_0's geometric mean: 0.763647
# [134]	valid_0's geometric mean: 0.763078
# [135]	valid_0's geometric mean: 0.763647
# [136]	valid_0's geometric mean: 0.76321
# [137]	valid_0's geometric mean: 0.763035
# [138]	valid_0's geometric mean: 0.763822
# [139]	valid_0's geometric mean: 0.763822
# [140]	valid_0's geometric mean: 0.763254
# [141]	valid_0's geometric mean: 0.763254
# [142]	valid_0's geometric mean: 0.76369
# [143]	valid_0's geometric mean: 0.764302
# [144]	valid_0's geometric mean: 0.76369
# [145]	valid_0's geometric mean: 0.76312
# [146]	valid_0's geometric mean: 0.763472
# [147]	valid_0's geometric mean: 0.764695
# [148]	valid_0's geometric mean: 0.763822
# [149]	valid_0's geometric mean: 0.764214
# [150]	valid_0's geometric mean: 0.763777
# [151]	valid_0's geometric mean: 0.765218
# [152]	valid_0's geometric mean: 0.764214
# [153]	valid_0's geometric mean: 0.765218
# [154]	valid_0's geometric mean: 0.764259
# [155]	valid_0's geometric mean: 0.764652
# [156]	valid_0's geometric mean: 0.765089
# [157]	valid_0's geometric mean: 0.765482
# [158]	valid_0's geometric mean: 0.76653
# [159]	valid_0's geometric mean: 0.76653
# [160]	valid_0's geometric mean: 0.76653
# [161]	valid_0's geometric mean: 0.766923
# [162]	valid_0's geometric mean: 0.767361
# [163]	valid_0's geometric mean: 0.767361
# [164]	valid_0's geometric mean: 0.767709
# [165]	valid_0's geometric mean: 0.76749
# [166]	valid_0's geometric mean: 0.768274
# [167]	valid_0's geometric mean: 0.767663
# [168]	valid_0's geometric mean: 0.766833
# [169]	valid_0's geometric mean: 0.767444
# [170]	valid_0's geometric mean: 0.767097
# [171]	valid_0's geometric mean: 0.767836
# [172]	valid_0's geometric mean: 0.767617
# [173]	valid_0's geometric mean: 0.766833
# [174]	valid_0's geometric mean: 0.76818
# [175]	valid_0's geometric mean: 0.768008
# [176]	valid_0's geometric mean: 0.767617
# [177]	valid_0's geometric mean: 0.768008
# [178]	valid_0's geometric mean: 0.768447
# [179]	valid_0's geometric mean: 0.768447
# [180]	valid_0's geometric mean: 0.768619
# [181]	valid_0's geometric mean: 0.768055
# [182]	valid_0's geometric mean: 0.768666
# [183]	valid_0's geometric mean: 0.768838
# [184]	valid_0's geometric mean: 0.76901
# [185]	valid_0's geometric mean: 0.769182
# [186]	valid_0's geometric mean: 0.768008
# [187]	valid_0's geometric mean: 0.768619
# [188]	valid_0's geometric mean: 0.76923
# [189]	valid_0's geometric mean: 0.769841
# [190]	valid_0's geometric mean: 0.769449
# [191]	valid_0's geometric mean: 0.770012
# [192]	valid_0's geometric mean: 0.770232
# [193]	valid_0's geometric mean: 0.770012
# [194]	valid_0's geometric mean: 0.771233
# [195]	valid_0's geometric mean: 0.77006
# [196]	valid_0's geometric mean: 0.769669
# [197]	valid_0's geometric mean: 0.770842
# [198]	valid_0's geometric mean: 0.770499
# [199]	valid_0's geometric mean: 0.769888
# [200]	valid_0's geometric mean: 0.770718
# [201]	valid_0's geometric mean: 0.770327
# [202]	valid_0's geometric mean: 0.769543
# [203]	valid_0's geometric mean: 0.770718
# [204]	valid_0's geometric mean: 0.770938
# [205]	valid_0's geometric mean: 0.770938
# [206]	valid_0's geometric mean: 0.771329
# [207]	valid_0's geometric mean: 0.77089
# [208]	valid_0's geometric mean: 0.77089
# [209]	valid_0's geometric mean: 0.77028
# [210]	valid_0's geometric mean: 0.769449
# [211]	valid_0's geometric mean: 0.769449
# [212]	valid_0's geometric mean: 0.770107
# [213]	valid_0's geometric mean: 0.770107
# [214]	valid_0's geometric mean: 0.769888
# [215]	valid_0's geometric mean: 0.769669
# [216]	valid_0's geometric mean: 0.769669
# [217]	valid_0's geometric mean: 0.769888
# [218]	valid_0's geometric mean: 0.769888
# [219]	valid_0's geometric mean: 0.769888
# [220]	valid_0's geometric mean: 0.769888
# [221]	valid_0's geometric mean: 0.770499
# [222]	valid_0's geometric mean: 0.769716
# [223]	valid_0's geometric mean: 0.770107
# [224]	valid_0's geometric mean: 0.770107
# [225]	valid_0's geometric mean: 0.770107
# [226]	valid_0's geometric mean: 0.770107
# [227]	valid_0's geometric mean: 0.770107
# [228]	valid_0's geometric mean: 0.770107
# [229]	valid_0's geometric mean: 0.770107
# [230]	valid_0's geometric mean: 0.770107
# [231]	valid_0's geometric mean: 0.770107
# [232]	valid_0's geometric mean: 0.770107
# [233]	valid_0's geometric mean: 0.770107
# [234]	valid_0's geometric mean: 0.770107
# [235]	valid_0's geometric mean: 0.770107
# [236]	valid_0's geometric mean: 0.770107
# [237]	valid_0's geometric mean: 0.770107
# [238]	valid_0's geometric mean: 0.770107
# [239]	valid_0's geometric mean: 0.770107
# [240]	valid_0's geometric mean: 0.770107
# [241]	valid_0's geometric mean: 0.770107
# [242]	valid_0's geometric mean: 0.770107
# [243]	valid_0's geometric mean: 0.770107
# [244]	valid_0's geometric mean: 0.770107
# [245]	valid_0's geometric mean: 0.770107
# [246]	valid_0's geometric mean: 0.770107
# [247]	valid_0's geometric mean: 0.770107
# [248]	valid_0's geometric mean: 0.770107
# [249]	valid_0's geometric mean: 0.770107
# [250]	valid_0's geometric mean: 0.770107
# [251]	valid_0's geometric mean: 0.770107
# [252]	valid_0's geometric mean: 0.770107
# [253]	valid_0's geometric mean: 0.770107
# [254]	valid_0's geometric mean: 0.770107
# [255]	valid_0's geometric mean: 0.770107
# [256]	valid_0's geometric mean: 0.770107
# Early stopping, best iteration is:
# [206]	valid_0's geometric mean: 0.771329

# %%
df_preeval_test = make_preevaluation_df(
    clf, data['x_test'], data['xtra_cols_test'], data['y_test'],
    [ID_COLUMN, DATE_COLUMN] + ['AvaOpportunityId'])
df_preeval_test
# Out:
#                                          id            dateTime  \
# 17387  110fb940-9a06-41af-a533-3fb9615293cd 2020-02-26 00:45:21
# 17388  559adcce-9adf-4dbf-8b19-a2378f572942 2020-02-26 04:29:15
# 17389  3704d4fc-7e89-44d2-9b00-6e363885d3f3 2020-02-26 09:56:41
# 17390  733cf839-6a48-436f-801e-863a8a18bacd 2020-02-26 10:04:49
# 17391  dc981c3b-020d-4734-939f-71a9e8bb3538 2020-02-26 10:07:59
# ...                                     ...                 ...
# 18037  819403b7-2b04-476d-b9e0-6aeedcb532e1 2020-06-23 00:22:25
# 18038  072bbdf3-9e2e-4980-a37b-ae955693a744 2020-06-23 16:54:10
# 18039  1942d87c-8cbe-4198-97cf-4dfc80aed195 2020-06-23 18:01:22
# 18040  fec55fb7-9bbf-48d3-8db6-cd101124773a 2020-06-24 07:23:29
# 18041  4f5746e7-623c-4099-8703-8ffc73ed944c 2020-06-25 21:17:02
#
#       AvaOpportunityId  Probability  Label
# 17387       A000227053     0.903614      1
# 17388       A000227059     0.403573      0
# 17389       A000227068     0.941018      1
# 17390       A000227069     0.901812      1
# 17391       A000227070     0.512002      1
# ...                ...          ...    ...
# 18037       A000236549     0.929687      0
# 18038       A000236630     0.939531      1
# 18039       A000236633     0.425460      0
# 18040       A000236662     0.336744      0
# 18041       A000236865     0.929847      1
#
# [655 rows x 5 columns]

# %%
geometric_mean_score(df_preeval_test['Label'], [1 if y >= 0.5 else 0 for y in df_preeval_test['Probability']])
# Out:
# 0.7627762243310613

# %%
('metric name', 0.7627762243310613, 1)

# %%
# calculate accuracy metrics
metrics, conf_to_log, conf = get_metrics(df_preeval_test)
print("confusion matrix:\n", conf)
metrics
# Out:
# confusion matrix:
#           index  predFALSE  predTRUE
# 0  actualFALSE        147        61
# 1   actualTRUE         79       368
# {'accuracy': 0.7862595419847328,
#  'precision': 0.8578088578088578,
#  'recall': 0.8232662192393736,
#  'geometric_mean': 0.7627762243310613,
#  'f1': 0.8401826484018265}

# %%
# OUTPUTS
# log metrics
run = Run.get_context()
run.log("Arguments", args)
run.log('majority_obs', np.sum(data['y_valid'] == 0))
run.log('minority obs', np.sum(data['y_valid'] == 1))
run.log('precision', metrics['precision'])
run.log('recall', metrics['recall'])
run.log('f1', metrics['f1'])
run.log('geometric mean', metrics['geometric_mean'])
run.log('LIFT', lift)

# %%
# save model
os.makedirs(args.output_dir, exist_ok=True)
os.makedirs('outputs', exist_ok=True)

joblib.dump(value=clf, filename=os.path.join('outputs', args.model_name + '.pkl'))
joblib.dump(value=clf, filename=os.path.join(args.output_dir, args.model_name + '.pkl'))
